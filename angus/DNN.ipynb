# %% [markdown]
# # DNN
# 1. 把all_keys.csv, ESun_public_y_answer.csv加到工作區
# 2. 調整 # Main 下方的兩個block，第一個調參數，第二個建network
# 3. 其他block應該不需要動
# 4. 最後一個block會印成績

# %%
import numpy as np
import pandas as pd
import csv
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
import math

# %% [markdown]
# # Read data

# %%
#!gdown 1vHDhZSPmhithLVRRzkNw0ak_kk7PhInu # V_trade
#!gdown 145T8z3XXlsaISzWdrJgJVANGokG1XuFI # V_remit
#!gdown 1AubrUmeNUgpgiOu4tay6Gwl8O3lBaokF # V_info
#!gdown 1zZo9RLt3mMmJZxEETSY2g9ND31qkZIn0 # V_cred
#!gdown 1uFCx21bqE3FnrdfvN_mwtw2-nvogTEex # V_cons
#!gdown 1ZOXGT_rIdEGIliHGKEH3ha77ZlZyq1Gn # train_y
#!gdown 1qjEwmi97OWdshSNdgQj2ccXnoM4UvT25 # V_trade_public
#!gdown 1g8trBiC6OxuoTU94u_UMygVrA-fSASpB # V_remit_public
#!gdown 14KTfY56Mz2xBXdP27GvGB2HVeb_4Ks4T # V_info_public
#!gdown 1EaIWnjQxUl4KRgVCqYT7AB4PaSNvc_GL # V_cred_public
#!gdown 1owf1urxHZywAxJfCgVXCpXEMQ6VZGhnO # V_cons_public
#!gdown 1LbF8RTlCAuSm_78kA7oLaj91MxlZqhro # public_y

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
V_cons = pd.read_csv('/content/drive/MyDrive/ml_proj/V_cons.csv').iloc[:, 1:]
V_cred = pd.read_csv('/content/drive/MyDrive/ml_proj/V_cred.csv').iloc[:, 1:]
V_info = pd.read_csv('/content/drive/MyDrive/ml_proj/V_info.csv').iloc[:, 1:]
V_remit = pd.read_csv('/content/drive/MyDrive/ml_proj/V_remit.csv').iloc[:, 1:]
V_trade = pd.read_csv('/content/drive/MyDrive/ml_proj/V_trade.csv').iloc[:, 1:]
train_y = pd.read_csv('/content/drive/MyDrive/ml_proj/train_y.csv').iloc[:, 1:]

V_cons_public = pd.read_csv('/content/drive/MyDrive/ml_proj/V_cons_public.csv').iloc[:, 1:]
V_cred_public = pd.read_csv('/content/drive/MyDrive/ml_proj/V_cred_public.csv').iloc[:, 1:]
V_info_public = pd.read_csv('/content/drive/MyDrive/ml_proj/V_info_public.csv').iloc[:, 1:]
V_remit_public = pd.read_csv('/content/drive/MyDrive/ml_proj/V_remit_public.csv').iloc[:, 1:]
V_trade_public = pd.read_csv('/content/drive/MyDrive/ml_proj/V_trade_public.csv').iloc[:, 1:]
public_y = pd.read_csv('/content/drive/MyDrive/ml_proj/public_y.csv').iloc[:, 1:]

all_keys = pd.read_csv('/content/drive/MyDrive/ml_proj/DNN/all_keys.csv')
ESun_public_y_answer = pd.read_csv('/content/drive/MyDrive/ml_proj/DNN/ESun_public_y_answer.csv')

# %%
#V_cons = pd.read_csv('V_cons.csv').iloc[:, 1:]
#V_cred = pd.read_csv('V_cred.csv').iloc[:, 1:]
#V_info = pd.read_csv('V_info.csv').iloc[:, 1:]
#V_remit = pd.read_csv('V_remit.csv').iloc[:, 1:]
#V_trade = pd.read_csv('V_trade.csv').iloc[:, 1:]
#train_y = pd.read_csv('train_y.csv').iloc[:, 1:]

#V_cons_public = pd.read_csv('V_cons_public.csv').iloc[:, 1:]
#V_cred_public = pd.read_csv('V_cred_public.csv').iloc[:, 1:]
#V_info_public = pd.read_csv('V_info_public.csv').iloc[:, 1:]
#V_remit_public = pd.read_csv('V_remit_public.csv').iloc[:, 1:]
#V_trade_public = pd.read_csv('V_trade_public.csv').iloc[:, 1:]
#public_y = pd.read_csv('public_y.csv').iloc[:, 1:]

#all_keys = pd.read_csv('all_keys.csv')
#ESun_public_y_answer = pd.read_csv('ESun_public_y_answer.csv')

# %%
V_overall = pd.concat([V_info, V_cred, V_cons, V_remit, V_trade], axis=1).fillna(0)
V_overall_public = pd.concat([V_info_public, V_cred_public, V_cons_public, V_remit_public, V_trade_public], axis=1).fillna(0)

# %%
print(V_info.shape)
print(V_cred.shape)
print(V_cons.shape)
print(V_remit.shape)
print(V_trade.shape)
print(V_overall.shape)
print()
print(V_info_public.shape)
print(V_cred_public.shape)
print(V_cons_public.shape)
print(V_remit_public.shape)
print(V_trade_public.shape)
print(V_overall_public.shape)
print()
print(train_y.shape)
print(public_y.shape)
print()
print(all_keys.shape)
print(ESun_public_y_answer.shape)
# Out:
# (23906, 4)
# (23906, 117)
# (23906, 1965)
# (23906, 1572)
# (23906, 3537)
# (23906, 7195)
#
# (1845, 4)
# (1845, 117)
# (1845, 1965)
# (1845, 1572)
# (1845, 3537)
# (1845, 7195)
#
# (23906, 1)
# (1845, 1)
#
# (25751, 1)
# (1845, 2)

# %%
# instance = torch.tensor(V_overall.values).to(torch.float32)
# print(torch.any(torch.isnan(instance)))
# for row in range(len(instance)):
#     for i in instance[row]:
#         if torch.isnan(i):
#             print(row, instance[row])

# %%
print(public_y)
print(public_y.sum())
# Out:
#       0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 1840  0
# 1841  0
# 1842  0
# 1843  0
# 1844  0
#
# [1845 rows x 1 columns]
# 0    11
# dtype: int64

# %%
public_y
# Out:
#       0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 1840  0
# 1841  0
# 1842  0
# 1843  0
# 1844  0
#
# [1845 rows x 1 columns]

# %% [markdown]
# # Main

# %%
# set parameters
n_epoch = 500
batch = 128 #
lr = 0.0000001
w = 1
d = 99 # duplicate d times for SAR_flag == 1 (oversampling)

# %%
# define network
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.network = nn.Sequential( # 7195 -> 1
            nn.Linear(7195, 2048),
            nn.ReLU(),
            nn.Linear(2048, 1024),
            nn.ReLU(),
            nn.Linear(1024, 128),
            nn.ReLU(),
            nn.Linear(128, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid() # last one must be sigmoid 
        )
                
    def forward(self, x):
        x = self.network(x)
        return x

# %%
def loss_function(prob, ans):
    #print(prob, ans)
    return (w * (1 - prob) * ans + (prob) * (1 - ans))

# %%
def train(train_data, val_data, model, n_epoch, batch, lr, device):
    
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)
    best_loss = 1000000
    for epoch in range(n_epoch):
        total_loss = 0
        model.train()
        idx = 0
        for data, ans in train_data:
            data, ans = data.to(device), ans.to(device)
            prob = model(data)
            loss = torch.sum(loss_function(prob, ans)) / batch
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += (loss.item() / len(train_data))
            print('[Epoch %d | %d/%d] loss: %.4f' % ((epoch+1), idx*batch, len(train_data) * batch, loss.item()), end='\r')
            idx += 1
        print("\n  Training  | Loss:%.4f " % total_loss)

        # validation set
        model.eval()
        total_loss = 0
        idx = 0 
        with torch.no_grad():
            for data, ans in val_data:
                data, ans = data.to(device), ans.to(device)
                prob = model(data)
                loss = torch.sum(loss_function(prob, ans)) / batch
                total_loss += (loss.item() / len(val_data))
                idx += 1
            print(" Validation | Loss:%.4f " % total_loss)
        # save model
        if total_loss < best_loss:
                best_loss = total_loss
                print("saving model with loss %.4f...\n" % total_loss)
                torch.save(model.state_dict(), "%s" % "model.pth")
    return model

# %%
class TrainDataset(Dataset):
    def __init__(self):
        # oversampling
        print("Train")
        V_overall_list = V_overall.values.tolist()
        train_y_list = train_y.values.tolist()
        l = len(train_y_list)
        s = sum(sum(train_y_list,[]))
        print("Before: total=:", l, "flag=0:", l - s, "flag=1:", s, "SAR_rate=", s / l)        
        for i in range(l):
            if train_y_list[i][0] == 1:
                V_overall_list.extend([V_overall_list[i] for j in range(d)])
                train_y_list.extend([train_y_list[i] for j in range(d)])
        l = len(train_y_list)
        s = sum(sum(train_y_list,[]))
        print("After: total=:", l, "flag=0:", l - s, "flag=1:", s, "SAR_rate=", s / l)    
        
        self.X = torch.tensor(V_overall_list).to(torch.float32)
        self.Y = torch.tensor(train_y_list).to(torch.float32)
  
    def __len__(self):
        return self.X.size(0)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]

class ValDataset(Dataset):
    def __init__(self):
        print("Val")
        V_overall_public_list = V_overall_public.values.tolist()
        train_y_public_list = public_y.values.tolist()
        l = len(train_y_public_list)
        s = sum(sum(train_y_public_list,[]))
        print("Before: total=:", l, "flag=0:", l - s, "flag=1:", s, "SAR_rate=", s / l)        
        for i in range(l):
            if train_y_public_list[i][0] == 1:
                V_overall_public_list.extend([V_overall_public_list[i] for j in range(d)])
                train_y_public_list.extend([train_y_public_list[i] for j in range(d)])
        l = len(train_y_public_list)
        s = sum(sum(train_y_public_list,[]))
        print("After: total=:", l, "flag=0:", l - s, "flag=1:", s, "SAR_rate=", s / l)    
        
        self.X = torch.tensor(V_overall_public_list).to(torch.float32)
        self.Y = torch.tensor(train_y_public_list).to(torch.float32)

    def __len__(self):
        return self.X.size(0)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]
    
class TestDataset(Dataset):
    def __init__(self):
        self.X = torch.tensor(V_overall_public.values).to(torch.float32)
        self.Y = torch.tensor(public_y.values).to(torch.float32)

    def __len__(self):
        return self.X.size(0)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]

# %%
trainset = TrainDataset()
valset = ValDataset()
train_dataloader = DataLoader(trainset, batch, True)
val_dataloader = DataLoader(valset, batch, True)
# Out:
# Train
# Before: total=: 23906 flag=0: 23672 flag=1: 234 SAR_rate= 0.009788337655818623
# After: total=: 47072 flag=0: 23672 flag=1: 23400 SAR_rate= 0.4971108089734874
# Val
# Before: total=: 1845 flag=0: 1834 flag=1: 11 SAR_rate= 0.005962059620596206
# After: total=: 2934 flag=0: 1834 flag=1: 1100 SAR_rate= 0.37491479209270623

# %%
device = 'cuda:0'
model = Net().to(device) 
model = train(train_dataloader, val_dataloader, model, n_epoch, batch, lr, device)
# Out:
# [Epoch 1 | 46976/47104] loss: 0.3797
#   Training  | Loss:0.5105
#  Validation | Loss:0.3780
# saving model with loss 0.3780...
#
# [Epoch 2 | 46976/47104] loss: 0.3984
#   Training  | Loss:0.5047
#  Validation | Loss:0.3776
# saving model with loss 0.3776...
#
# [Epoch 3 | 46976/47104] loss: 0.4215
#   Training  | Loss:0.5018
#  Validation | Loss:0.3775
# saving model with loss 0.3775...
#
# [Epoch 4 | 46976/47104] loss: 0.3537
#   Training  | Loss:0.5012
#  Validation | Loss:0.3774
# saving model with loss 0.3774...
#
# [Epoch 5 | 46976/47104] loss: 0.3609
#   Training  | Loss:0.5008
#  Validation | Loss:0.3770
# saving model with loss 0.3770...
#
#
#   Training  | Loss:0.5005
#  Validation | Loss:0.3769
# saving model with loss 0.3769...
#
# [Epoch 7 | 46976/47104] loss: 0.3247
#   Training  | Loss:0.5003
#  Validation | Loss:0.3767
# saving model with loss 0.3767...
#
# [Epoch 8 | 46976/47104] loss: 0.3679
#   Training  | Loss:0.4999
#  Validation | Loss:0.3767
# saving model with loss 0.3767...
#
# [Epoch 9 | 46976/47104] loss: 0.4443
#   Training  | Loss:0.4991
#  Validation | Loss:0.3766
# saving model with loss 0.3766...
#
# [Epoch 10 | 46976/47104] loss: 0.3333
#   Training  | Loss:0.4985
#  Validation | Loss:0.3763
# saving model with loss 0.3763...
#
# [Epoch 11 | 46976/47104] loss: 0.3757
#   Training  | Loss:0.4982
#  Validation | Loss:0.3761
# saving model with loss 0.3761...
#
# [Epoch 12 | 46976/47104] loss: 0.4297
#   Training  | Loss:0.4979
#  Validation | Loss:0.3761
# saving model with loss 0.3761...
#
# [Epoch 13 | 46976/47104] loss: 0.4429
#   Training  | Loss:0.4976
#  Validation | Loss:0.3757
# saving model with loss 0.3757...
#
# [Epoch 14 | 46976/47104] loss: 0.3452
#   Training  | Loss:0.4974
#  Validation | Loss:0.3757
# saving model with loss 0.3757...
#
# [Epoch 15 | 46976/47104] loss: 0.4183
#   Training  | Loss:0.4973
#  Validation | Loss:0.3757
# saving model with loss 0.3757...
#
# [Epoch 16 | 46976/47104] loss: 0.3160
#   Training  | Loss:0.4972
#  Validation | Loss:0.3757
# saving model with loss 0.3757...
#
# [Epoch 17 | 46976/47104] loss: 0.3270
#   Training  | Loss:0.4970
#  Validation | Loss:0.3757
# saving model with loss 0.3757...
#
# [Epoch 18 | 46976/47104] loss: 0.3296
#   Training  | Loss:0.4968
#  Validation | Loss:0.3757
# saving model with loss 0.3757...
#
# [Epoch 19 | 46976/47104] loss: 0.3532
#   Training  | Loss:0.4967
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 20 | 46976/47104] loss: 0.3949
#   Training  | Loss:0.4966
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 21 | 46976/47104] loss: 0.3235
#   Training  | Loss:0.4965
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 22 | 46976/47104] loss: 0.3607
#   Training  | Loss:0.4964
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 23 | 46976/47104] loss: 0.3521
#   Training  | Loss:0.4963
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 24 | 46976/47104] loss: 0.3376
#   Training  | Loss:0.4962
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 25 | 46976/47104] loss: 0.3419
#   Training  | Loss:0.4962
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 26 | 46976/47104] loss: 0.3624
#   Training  | Loss:0.4961
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 27 | 46976/47104] loss: 0.3601
#   Training  | Loss:0.4960
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 28 | 46976/47104] loss: 0.4113
#   Training  | Loss:0.4960
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 29 | 46976/47104] loss: 0.3935
#   Training  | Loss:0.4959
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 30 | 46976/47104] loss: 0.3528
#   Training  | Loss:0.4958
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 31 | 46976/47104] loss: 0.3646
#   Training  | Loss:0.4958
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 32 | 46976/47104] loss: 0.3957
#   Training  | Loss:0.4957
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 33 | 46976/47104] loss: 0.3564
#   Training  | Loss:0.4957
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 34 | 46976/47104] loss: 0.3281
#   Training  | Loss:0.4956
#  Validation | Loss:0.3756
# saving model with loss 0.3756...
#
# [Epoch 35 | 46976/47104] loss: 0.4027
#   Training  | Loss:0.4956
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 36 | 46976/47104] loss: 0.4105
#   Training  | Loss:0.4955
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 37 | 46976/47104] loss: 0.3555
#   Training  | Loss:0.4955
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 38 | 46976/47104] loss: 0.3756
#   Training  | Loss:0.4954
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 39 | 46976/47104] loss: 0.3359
#   Training  | Loss:0.4954
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 40 | 46976/47104] loss: 0.3521
#   Training  | Loss:0.4953
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 41 | 46976/47104] loss: 0.4228
#   Training  | Loss:0.4952
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 42 | 46976/47104] loss: 0.3230
#   Training  | Loss:0.4952
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 43 | 46976/47104] loss: 0.3380
#   Training  | Loss:0.4951
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 44 | 46976/47104] loss: 0.3557
#   Training  | Loss:0.4951
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 45 | 46976/47104] loss: 0.3801
#   Training  | Loss:0.4950
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 46 | 46976/47104] loss: 0.4385
#   Training  | Loss:0.4950
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 47 | 46976/47104] loss: 0.3937
#   Training  | Loss:0.4949
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 48 | 46976/47104] loss: 0.3757
#   Training  | Loss:0.4948
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 49 | 46976/47104] loss: 0.4262
#   Training  | Loss:0.4948
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 50 | 46976/47104] loss: 0.3286
#   Training  | Loss:0.4947
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 51 | 46976/47104] loss: 0.3175
#   Training  | Loss:0.4947
#  Validation | Loss:0.3755
# saving model with loss 0.3755...
#
# [Epoch 52 | 46976/47104] loss: 0.3324
#   Training  | Loss:0.4946
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 53 | 46976/47104] loss: 0.3989
#   Training  | Loss:0.4945
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 54 | 46976/47104] loss: 0.4183
#   Training  | Loss:0.4945
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 55 | 46976/47104] loss: 0.3869
#   Training  | Loss:0.4944
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 56 | 46976/47104] loss: 0.3447
#   Training  | Loss:0.4944
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 57 | 46976/47104] loss: 0.3750
#   Training  | Loss:0.4943
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 58 | 46976/47104] loss: 0.3245
#   Training  | Loss:0.4943
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 59 | 46976/47104] loss: 0.3638
#   Training  | Loss:0.4942
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 60 | 46976/47104] loss: 0.4260
#   Training  | Loss:0.4941
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 61 | 46976/47104] loss: 0.3483
#   Training  | Loss:0.4941
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 62 | 46976/47104] loss: 0.3559
#   Training  | Loss:0.4940
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 63 | 46976/47104] loss: 0.3642
#   Training  | Loss:0.4940
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 64 | 46976/47104] loss: 0.4070
#   Training  | Loss:0.4939
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 65 | 46976/47104] loss: 0.3359
#   Training  | Loss:0.4938
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 66 | 46976/47104] loss: 0.3828
#   Training  | Loss:0.4938
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 67 | 46976/47104] loss: 0.3830
#   Training  | Loss:0.4937
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 68 | 46976/47104] loss: 0.3365
#   Training  | Loss:0.4937
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 69 | 46976/47104] loss: 0.3277
#   Training  | Loss:0.4936
#  Validation | Loss:0.3754
# saving model with loss 0.3754...
#
# [Epoch 70 | 46976/47104] loss: 0.3565
#   Training  | Loss:0.4936
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 71 | 46976/47104] loss: 0.3279
#   Training  | Loss:0.4935
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 72 | 46976/47104] loss: 0.3946
#   Training  | Loss:0.4935
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 73 | 46976/47104] loss: 0.4175
#   Training  | Loss:0.4934
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 74 | 46976/47104] loss: 0.2987
#   Training  | Loss:0.4934
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 75 | 46976/47104] loss: 0.4173
#   Training  | Loss:0.4933
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 76 | 46976/47104] loss: 0.4017
#   Training  | Loss:0.4932
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 77 | 46976/47104] loss: 0.3641
#   Training  | Loss:0.4932
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 78 | 46976/47104] loss: 0.3928
#   Training  | Loss:0.4931
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 79 | 46976/47104] loss: 0.3946
#   Training  | Loss:0.4931
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 80 | 46976/47104] loss: 0.3897
#   Training  | Loss:0.4930
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 81 | 46976/47104] loss: 0.3750
#   Training  | Loss:0.4929
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 82 | 46976/47104] loss: 0.3203
#   Training  | Loss:0.4929
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 83 | 46976/47104] loss: 0.3088
#   Training  | Loss:0.4928
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 84 | 46976/47104] loss: 0.3475
#   Training  | Loss:0.4928
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 85 | 46976/47104] loss: 0.4023
#   Training  | Loss:0.4927
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 86 | 46976/47104] loss: 0.4025
#   Training  | Loss:0.4926
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 87 | 46976/47104] loss: 0.3672
#   Training  | Loss:0.4926
#  Validation | Loss:0.3753
# saving model with loss 0.3753...
#
# [Epoch 88 | 46976/47104] loss: 0.3451
#   Training  | Loss:0.4925
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 89 | 46976/47104] loss: 0.3005
#   Training  | Loss:0.4924
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 90 | 46976/47104] loss: 0.3403
#   Training  | Loss:0.4924
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 91 | 46976/47104] loss: 0.3552
#   Training  | Loss:0.4923
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 92 | 46976/47104] loss: 0.3448
#   Training  | Loss:0.4923
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 93 | 46976/47104] loss: 0.3472
#   Training  | Loss:0.4922
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 94 | 46976/47104] loss: 0.3630
#   Training  | Loss:0.4921
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 95 | 46976/47104] loss: 0.3664
#   Training  | Loss:0.4921
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 96 | 46976/47104] loss: 0.3400
#   Training  | Loss:0.4920
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 97 | 46976/47104] loss: 0.4252
#   Training  | Loss:0.4919
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 98 | 46976/47104] loss: 0.3452
#   Training  | Loss:0.4919
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 99 | 46976/47104] loss: 0.3105
#   Training  | Loss:0.4919
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 100 | 46976/47104] loss: 0.3084
#   Training  | Loss:0.4933
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 101 | 46976/47104] loss: 0.3740
#   Training  | Loss:0.4920
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 102 | 46976/47104] loss: 0.3963
#   Training  | Loss:0.4917
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 103 | 46976/47104] loss: 0.4099
#   Training  | Loss:0.4916
#  Validation | Loss:0.3752
# saving model with loss 0.3752...
#
# [Epoch 104 | 46976/47104] loss: 0.3978
#   Training  | Loss:0.4916
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 105 | 46976/47104] loss: 0.3880
#   Training  | Loss:0.4915
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 106 | 46976/47104] loss: 0.2344
#   Training  | Loss:0.4915
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 107 | 46976/47104] loss: 0.3509
#   Training  | Loss:0.4914
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 108 | 46976/47104] loss: 0.3719
#   Training  | Loss:0.4914
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 109 | 46976/47104] loss: 0.3341
#   Training  | Loss:0.4913
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 110 | 46976/47104] loss: 0.3783
#   Training  | Loss:0.4913
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 111 | 46976/47104] loss: 0.3501
#   Training  | Loss:0.4912
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 112 | 46976/47104] loss: 0.3804
#   Training  | Loss:0.4912
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 113 | 46976/47104] loss: 0.4114
#   Training  | Loss:0.4911
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 114 | 46976/47104] loss: 0.3489
#   Training  | Loss:0.4911
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 115 | 46976/47104] loss: 0.3080
#   Training  | Loss:0.4910
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 116 | 46976/47104] loss: 0.3585
#   Training  | Loss:0.4910
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 117 | 46976/47104] loss: 0.3521
#   Training  | Loss:0.4909
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 118 | 46976/47104] loss: 0.2963
#   Training  | Loss:0.4909
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 119 | 46976/47104] loss: 0.3628
#   Training  | Loss:0.4908
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 120 | 46976/47104] loss: 0.2977
#   Training  | Loss:0.4907
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 121 | 46976/47104] loss: 0.3390
#   Training  | Loss:0.4907
#  Validation | Loss:0.3751
# saving model with loss 0.3751...
#
# [Epoch 122 | 46976/47104] loss: 0.3281
#   Training  | Loss:0.4906
#  Validation | Loss:0.3750
# saving model with loss 0.3750...
#
# [Epoch 123 | 46976/47104] loss: 0.3783
#   Training  | Loss:0.4905
#  Validation | Loss:0.3750
# saving model with loss 0.3750...
#
# [Epoch 124 | 46976/47104] loss: 0.3516
#   Training  | Loss:0.4905
#  Validation | Loss:0.3750
# saving model with loss 0.3750...
#
# [Epoch 125 | 46976/47104] loss: 0.3756
#   Training  | Loss:0.4904
#  Validation | Loss:0.3750
# saving model with loss 0.3750...
#
# [Epoch 126 | 46976/47104] loss: 0.3828
#   Training  | Loss:0.4903
#  Validation | Loss:0.3750
# saving model with loss 0.3750...
#
# [Epoch 127 | 46976/47104] loss: 0.4095
#   Training  | Loss:0.4903
#  Validation | Loss:0.3750
# saving model with loss 0.3750...
#
# [Epoch 128 | 46976/47104] loss: 0.3378
#   Training  | Loss:0.4902
#  Validation | Loss:0.3750
# saving model with loss 0.3750...
#
# [Epoch 129 | 46976/47104] loss: 0.3631
#   Training  | Loss:0.4901
#  Validation | Loss:0.3750
# saving model with loss 0.3750...
#
# [Epoch 130 | 46976/47104] loss: 0.3610
#   Training  | Loss:0.4900
#  Validation | Loss:0.3750
# saving model with loss 0.3750...
#
# [Epoch 131 | 46976/47104] loss: 0.3991
#   Training  | Loss:0.4900
#  Validation | Loss:0.3750
# saving model with loss 0.3750...
#
# [Epoch 132 | 46976/47104] loss: 0.3156
#   Training  | Loss:0.4899
#  Validation | Loss:0.3750
# saving model with loss 0.3750...
#
# [Epoch 133 | 46976/47104] loss: 0.3750
#   Training  | Loss:0.4898
#  Validation | Loss:0.3750
# saving model with loss 0.3750...
#
# [Epoch 134 | 46976/47104] loss: 0.3967
#   Training  | Loss:0.4897
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 135 | 46976/47104] loss: 0.3624
#   Training  | Loss:0.4896
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 136 | 46976/47104] loss: 0.3033
#   Training  | Loss:0.4896
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 137 | 46976/47104] loss: 0.3467
#   Training  | Loss:0.4895
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 138 | 46976/47104] loss: 0.3858
#   Training  | Loss:0.4907
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 139 | 46976/47104] loss: 0.3289
#   Training  | Loss:0.4909
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 140 | 46976/47104] loss: 0.4355
#   Training  | Loss:0.4893
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 141 | 46976/47104] loss: 0.3522
#   Training  | Loss:0.4902
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 142 | 46976/47104] loss: 0.4033
#   Training  | Loss:0.4913
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 143 | 46976/47104] loss: 0.3962
#   Training  | Loss:0.4913
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 144 | 46976/47104] loss: 0.4004
#   Training  | Loss:0.4912
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 145 | 46976/47104] loss: 0.3728
#   Training  | Loss:0.4912
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 146 | 46976/47104] loss: 0.3477
#   Training  | Loss:0.4911
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 147 | 46976/47104] loss: 0.3594
#   Training  | Loss:0.4911
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 148 | 46976/47104] loss: 0.3393
#   Training  | Loss:0.4911
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 149 | 46976/47104] loss: 0.3401
#   Training  | Loss:0.4910
#  Validation | Loss:0.3749
# saving model with loss 0.3749...
#
# [Epoch 150 | 46976/47104] loss: 0.3780
#   Training  | Loss:0.4910
#  Validation | Loss:0.3748
# saving model with loss 0.3748...
#
# [Epoch 151 | 46976/47104] loss: 0.3960
#   Training  | Loss:0.4909
#  Validation | Loss:0.3748
# saving model with loss 0.3748...
#
# [Epoch 152 | 46976/47104] loss: 0.4200
#   Training  | Loss:0.4908
#  Validation | Loss:0.3748
# saving model with loss 0.3748...
#
# [Epoch 153 | 46976/47104] loss: 0.3598
#   Training  | Loss:0.4908
#  Validation | Loss:0.3748
# saving model with loss 0.3748...
#
# [Epoch 154 | 46976/47104] loss: 0.3517
#   Training  | Loss:0.4907
#  Validation | Loss:0.3748
# saving model with loss 0.3748...
#
# [Epoch 155 | 46976/47104] loss: 0.3488
#   Training  | Loss:0.4907
#  Validation | Loss:0.3748
# saving model with loss 0.3748...
#
# [Epoch 156 | 46976/47104] loss: 0.3645
#   Training  | Loss:0.4906
#  Validation | Loss:0.3748
# saving model with loss 0.3748...
#
# [Epoch 157 | 46976/47104] loss: 0.3415
#   Training  | Loss:0.4906
#  Validation | Loss:0.3748
# saving model with loss 0.3748...
#
# [Epoch 158 | 46976/47104] loss: 0.3385
#   Training  | Loss:0.4905
#  Validation | Loss:0.3748
# saving model with loss 0.3748...
#
# [Epoch 159 | 46976/47104] loss: 0.4322
#   Training  | Loss:0.4904
#  Validation | Loss:0.3748
# saving model with loss 0.3748...
#
# [Epoch 160 | 46976/47104] loss: 0.3594
#   Training  | Loss:0.4904
#  Validation | Loss:0.3748
# saving model with loss 0.3748...
#
# [Epoch 161 | 46976/47104] loss: 0.3909
#   Training  | Loss:0.4903
#  Validation | Loss:0.3748
# saving model with loss 0.3748...
#
#
#   Training  | Loss:0.4902
#  Validation | Loss:0.3748
# saving model with loss 0.3748...
#
# [Epoch 163 | 46976/47104] loss: 0.3559
#   Training  | Loss:0.4902
#  Validation | Loss:0.3747
# saving model with loss 0.3747...
#
# [Epoch 164 | 46976/47104] loss: 0.3563
#   Training  | Loss:0.4901
#  Validation | Loss:0.3747
# saving model with loss 0.3747...
#
# [Epoch 165 | 46976/47104] loss: 0.4000
#   Training  | Loss:0.4900
#  Validation | Loss:0.3747
# saving model with loss 0.3747...
#
# [Epoch 166 | 46976/47104] loss: 0.3672
#   Training  | Loss:0.4899
#  Validation | Loss:0.3747
# saving model with loss 0.3747...
#
# [Epoch 167 | 46976/47104] loss: 0.3775
#   Training  | Loss:0.4898
#  Validation | Loss:0.3747
# saving model with loss 0.3747...
#
# [Epoch 168 | 46976/47104] loss: 0.3743
#   Training  | Loss:0.4898
#  Validation | Loss:0.3747
# saving model with loss 0.3747...
#
# [Epoch 169 | 46976/47104] loss: 0.3672
#   Training  | Loss:0.4897
#  Validation | Loss:0.3747
# saving model with loss 0.3747...
#
# [Epoch 170 | 46976/47104] loss: 0.3403
#   Training  | Loss:0.4896
#  Validation | Loss:0.3747
# saving model with loss 0.3747...
#
# [Epoch 171 | 46976/47104] loss: 0.4297
#   Training  | Loss:0.4895
#  Validation | Loss:0.3747
# saving model with loss 0.3747...
#
# [Epoch 172 | 46976/47104] loss: 0.3763
#   Training  | Loss:0.4894
#  Validation | Loss:0.3746
# saving model with loss 0.3746...
#
# [Epoch 173 | 46976/47104] loss: 0.3382
#   Training  | Loss:0.4893
#  Validation | Loss:0.3746
# saving model with loss 0.3746...
#
# [Epoch 174 | 46976/47104] loss: 0.4259
#   Training  | Loss:0.4892
#  Validation | Loss:0.3746
# saving model with loss 0.3746...
#
# [Epoch 175 | 46976/47104] loss: 0.4164
#   Training  | Loss:0.4891
#  Validation | Loss:0.3746
# saving model with loss 0.3746...
#
# [Epoch 176 | 46976/47104] loss: 0.4257
#   Training  | Loss:0.4890
#  Validation | Loss:0.3746
# saving model with loss 0.3746...
#
# [Epoch 177 | 46976/47104] loss: 0.3594
#   Training  | Loss:0.4889
#  Validation | Loss:0.3746
# saving model with loss 0.3746...
#
# [Epoch 178 | 46976/47104] loss: 0.4022
#   Training  | Loss:0.4888
#  Validation | Loss:0.3746
# saving model with loss 0.3746...
#
# [Epoch 179 | 46976/47104] loss: 0.4022
#   Training  | Loss:0.4887
#  Validation | Loss:0.3746
# saving model with loss 0.3746...
#
# [Epoch 180 | 46976/47104] loss: 0.3537
#   Training  | Loss:0.4886
#  Validation | Loss:0.3745
# saving model with loss 0.3745...
#
# [Epoch 181 | 46976/47104] loss: 0.2848
#   Training  | Loss:0.4885
#  Validation | Loss:0.3745
# saving model with loss 0.3745...
#
# [Epoch 182 | 46976/47104] loss: 0.3332
#   Training  | Loss:0.4884
#  Validation | Loss:0.3745
# saving model with loss 0.3745...
#
# [Epoch 183 | 46976/47104] loss: 0.4173
#   Training  | Loss:0.4883
#  Validation | Loss:0.3745
# saving model with loss 0.3745...
#
# [Epoch 184 | 46976/47104] loss: 0.2940
#   Training  | Loss:0.4882
#  Validation | Loss:0.3745
# saving model with loss 0.3745...
#
# [Epoch 185 | 46976/47104] loss: 0.3781
#   Training  | Loss:0.4881
#  Validation | Loss:0.3745
# saving model with loss 0.3745...
#
# [Epoch 186 | 46976/47104] loss: 0.3311
#   Training  | Loss:0.4880
#  Validation | Loss:0.3745
# saving model with loss 0.3745...
#
# [Epoch 187 | 46976/47104] loss: 0.3231
#   Training  | Loss:0.4879
#  Validation | Loss:0.3744
# saving model with loss 0.3744...
#
# [Epoch 188 | 46976/47104] loss: 0.3608
#   Training  | Loss:0.4878
#  Validation | Loss:0.3744
# saving model with loss 0.3744...
#
# [Epoch 189 | 46976/47104] loss: 0.3420
#   Training  | Loss:0.4877
#  Validation | Loss:0.3744
# saving model with loss 0.3744...
#
# [Epoch 190 | 46976/47104] loss: 0.3920
#   Training  | Loss:0.4876
#  Validation | Loss:0.3744
# saving model with loss 0.3744...
#
# [Epoch 191 | 46976/47104] loss: 0.3828
#   Training  | Loss:0.4875
#  Validation | Loss:0.3744
# saving model with loss 0.3744...
#
#
#   Training  | Loss:0.4874
#  Validation | Loss:0.3744
# saving model with loss 0.3744...
#
# [Epoch 193 | 46976/47104] loss: 0.3359
#   Training  | Loss:0.4873
#  Validation | Loss:0.3744
# saving model with loss 0.3744...
#
# [Epoch 194 | 46976/47104] loss: 0.3145
#   Training  | Loss:0.4873
#  Validation | Loss:0.3743
# saving model with loss 0.3743...
#
# [Epoch 195 | 46976/47104] loss: 0.3262
#   Training  | Loss:0.4872
#  Validation | Loss:0.3743
# saving model with loss 0.3743...
#
# [Epoch 196 | 46976/47104] loss: 0.3225
#   Training  | Loss:0.4871
#  Validation | Loss:0.3743
# saving model with loss 0.3743...
#
# [Epoch 197 | 46976/47104] loss: 0.3928
#   Training  | Loss:0.4870
#  Validation | Loss:0.3743
# saving model with loss 0.3743...
#
# [Epoch 198 | 46976/47104] loss: 0.3912
#   Training  | Loss:0.4869
#  Validation | Loss:0.3743
# saving model with loss 0.3743...
#
# [Epoch 199 | 46976/47104] loss: 0.3047
#   Training  | Loss:0.4868
#  Validation | Loss:0.3743
# saving model with loss 0.3743...
#
# [Epoch 200 | 46976/47104] loss: 0.3482
#   Training  | Loss:0.4867
#  Validation | Loss:0.3743
# saving model with loss 0.3743...
#
# [Epoch 201 | 46976/47104] loss: 0.3525
#   Training  | Loss:0.4867
#  Validation | Loss:0.3742
# saving model with loss 0.3742...
#
# [Epoch 202 | 46976/47104] loss: 0.3604
#   Training  | Loss:0.4866
#  Validation | Loss:0.3742
# saving model with loss 0.3742...
#
# [Epoch 203 | 46976/47104] loss: 0.3993
#   Training  | Loss:0.4865
#  Validation | Loss:0.3742
# saving model with loss 0.3742...
#
# [Epoch 204 | 46976/47104] loss: 0.4552
#   Training  | Loss:0.4864
#  Validation | Loss:0.3742
# saving model with loss 0.3742...
#
# [Epoch 205 | 46976/47104] loss: 0.3524
#   Training  | Loss:0.4863
#  Validation | Loss:0.3742
# saving model with loss 0.3742...
#
# [Epoch 206 | 46976/47104] loss: 0.4303
#   Training  | Loss:0.4863
#  Validation | Loss:0.3742
# saving model with loss 0.3742...
#
# [Epoch 207 | 46976/47104] loss: 0.3914
#   Training  | Loss:0.4862
#  Validation | Loss:0.3742
# saving model with loss 0.3742...
#
# [Epoch 208 | 46976/47104] loss: 0.4255
#   Training  | Loss:0.4861
#  Validation | Loss:0.3741
# saving model with loss 0.3741...
#
# [Epoch 209 | 46976/47104] loss: 0.3145
#   Training  | Loss:0.4860
#  Validation | Loss:0.3741
# saving model with loss 0.3741...
#
# [Epoch 210 | 46976/47104] loss: 0.4013
#   Training  | Loss:0.4860
#  Validation | Loss:0.3741
# saving model with loss 0.3741...
#
# [Epoch 211 | 46976/47104] loss: 0.4310
#   Training  | Loss:0.4859
#  Validation | Loss:0.3741
# saving model with loss 0.3741...
#
# [Epoch 212 | 46976/47104] loss: 0.4346
#   Training  | Loss:0.4858
#  Validation | Loss:0.3741
# saving model with loss 0.3741...
#
# [Epoch 213 | 46976/47104] loss: 0.3516
#   Training  | Loss:0.4858
#  Validation | Loss:0.3741
# saving model with loss 0.3741...
#
# [Epoch 214 | 46976/47104] loss: 0.4453
#   Training  | Loss:0.4857
#  Validation | Loss:0.3741
# saving model with loss 0.3741...
#
# [Epoch 215 | 46976/47104] loss: 0.3750
#   Training  | Loss:0.4857
#  Validation | Loss:0.3741
# saving model with loss 0.3741...
#
# [Epoch 216 | 46976/47104] loss: 0.3771
#   Training  | Loss:0.4856
#  Validation | Loss:0.3740
# saving model with loss 0.3740...
#
# [Epoch 217 | 46976/47104] loss: 0.3750
#   Training  | Loss:0.4855
#  Validation | Loss:0.3740
# saving model with loss 0.3740...
#
# [Epoch 218 | 46976/47104] loss: 0.3842
#   Training  | Loss:0.4855
#  Validation | Loss:0.3740
# saving model with loss 0.3740...
#
# [Epoch 219 | 46976/47104] loss: 0.3837
#   Training  | Loss:0.4854
#  Validation | Loss:0.3740
# saving model with loss 0.3740...
#
# [Epoch 220 | 46976/47104] loss: 0.3602
#   Training  | Loss:0.4854
#  Validation | Loss:0.3740
# saving model with loss 0.3740...
#
# [Epoch 221 | 46976/47104] loss: 0.3372
#   Training  | Loss:0.4853
#  Validation | Loss:0.3740
# saving model with loss 0.3740...
#
# [Epoch 222 | 46976/47104] loss: 0.3594
#   Training  | Loss:0.4853
#  Validation | Loss:0.3740
# saving model with loss 0.3740...
#
# [Epoch 223 | 46976/47104] loss: 0.3220
#   Training  | Loss:0.4852
#  Validation | Loss:0.3740
# saving model with loss 0.3740...
#
# [Epoch 224 | 46976/47104] loss: 0.4062
#   Training  | Loss:0.4852
#  Validation | Loss:0.3740
# saving model with loss 0.3740...
#
# [Epoch 225 | 46976/47104] loss: 0.3913
#   Training  | Loss:0.4851
#  Validation | Loss:0.3740
# saving model with loss 0.3740...
#
# [Epoch 226 | 46976/47104] loss: 0.3610
#   Training  | Loss:0.4851
#  Validation | Loss:0.3739
# saving model with loss 0.3739...
#
# [Epoch 227 | 46976/47104] loss: 0.3209
#   Training  | Loss:0.4851
#  Validation | Loss:0.3739
# saving model with loss 0.3739...
#
# [Epoch 228 | 46976/47104] loss: 0.3449
#   Training  | Loss:0.4850
#  Validation | Loss:0.3739
# saving model with loss 0.3739...
#
# [Epoch 229 | 46976/47104] loss: 0.3675
#   Training  | Loss:0.4850
#  Validation | Loss:0.3739
# saving model with loss 0.3739...
#
# [Epoch 230 | 46976/47104] loss: 0.3442
#   Training  | Loss:0.4849
#  Validation | Loss:0.3739
# saving model with loss 0.3739...
#
# [Epoch 231 | 46976/47104] loss: 0.3443
#   Training  | Loss:0.4849
#  Validation | Loss:0.3739
# saving model with loss 0.3739...
#
# [Epoch 232 | 46976/47104] loss: 0.3383
#   Training  | Loss:0.4849
#  Validation | Loss:0.3739
# saving model with loss 0.3739...
#
# [Epoch 233 | 46976/47104] loss: 0.3440
#   Training  | Loss:0.4848
#  Validation | Loss:0.3739
# saving model with loss 0.3739...
#
# [Epoch 234 | 46976/47104] loss: 0.4062
#   Training  | Loss:0.4848
#  Validation | Loss:0.3739
# saving model with loss 0.3739...
#
# [Epoch 235 | 46976/47104] loss: 0.3831
#   Training  | Loss:0.4848
#  Validation | Loss:0.3739
# saving model with loss 0.3739...
#
# [Epoch 236 | 46976/47104] loss: 0.3049
#   Training  | Loss:0.4847
#  Validation | Loss:0.3739
# saving model with loss 0.3739...
#
# [Epoch 237 | 46976/47104] loss: 0.3986
#   Training  | Loss:0.4847
#  Validation | Loss:0.3739
# saving model with loss 0.3739...
#
# [Epoch 238 | 46976/47104] loss: 0.3287
#   Training  | Loss:0.4847
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 239 | 46976/47104] loss: 0.3995
#   Training  | Loss:0.4847
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 240 | 46976/47104] loss: 0.3284
#   Training  | Loss:0.4846
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 241 | 46976/47104] loss: 0.3053
#   Training  | Loss:0.4846
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 242 | 46976/47104] loss: 0.3907
#   Training  | Loss:0.4846
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 243 | 46976/47104] loss: 0.3750
#   Training  | Loss:0.4846
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 244 | 46976/47104] loss: 0.3445
#   Training  | Loss:0.4845
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 245 | 46976/47104] loss: 0.3054
#   Training  | Loss:0.4845
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 246 | 46976/47104] loss: 0.4300
#   Training  | Loss:0.4845
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 247 | 46976/47104] loss: 0.3517
#   Training  | Loss:0.4845
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 248 | 46976/47104] loss: 0.3916
#   Training  | Loss:0.4845
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 249 | 46976/47104] loss: 0.3444
#   Training  | Loss:0.4845
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 250 | 46976/47104] loss: 0.3379
#   Training  | Loss:0.4844
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 251 | 46976/47104] loss: 0.3828
#   Training  | Loss:0.4844
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 252 | 46976/47104] loss: 0.3829
#   Training  | Loss:0.4844
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 253 | 46976/47104] loss: 0.3519
#   Training  | Loss:0.4844
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 254 | 46976/47104] loss: 0.3439
#   Training  | Loss:0.4844
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 255 | 46976/47104] loss: 0.3672
#   Training  | Loss:0.4844
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 256 | 46976/47104] loss: 0.4144
#   Training  | Loss:0.4844
#  Validation | Loss:0.3738
# saving model with loss 0.3738...
#
# [Epoch 257 | 46976/47104] loss: 0.3517
#   Training  | Loss:0.4843
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 258 | 46976/47104] loss: 0.3676
#   Training  | Loss:0.4843
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 259 | 46976/47104] loss: 0.4067
#   Training  | Loss:0.4843
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 260 | 46976/47104] loss: 0.3828
#   Training  | Loss:0.4843
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 261 | 46976/47104] loss: 0.3985
#   Training  | Loss:0.4843
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 262 | 46976/47104] loss: 0.3517
#   Training  | Loss:0.4843
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 263 | 46976/47104] loss: 0.3987
#   Training  | Loss:0.4843
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 264 | 46976/47104] loss: 0.3126
#   Training  | Loss:0.4843
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 265 | 46976/47104] loss: 0.4063
#   Training  | Loss:0.4843
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 266 | 46976/47104] loss: 0.3516
#   Training  | Loss:0.4843
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 267 | 46976/47104] loss: 0.3438
#   Training  | Loss:0.4843
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 268 | 46976/47104] loss: 0.3985
#   Training  | Loss:0.4843
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 269 | 46976/47104] loss: 0.3594
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 270 | 46976/47104] loss: 0.3438
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 271 | 46976/47104] loss: 0.3051
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 272 | 46976/47104] loss: 0.4063
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 273 | 46976/47104] loss: 0.3203
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 274 | 46976/47104] loss: 0.3985
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 275 | 46976/47104] loss: 0.3906
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 276 | 46976/47104] loss: 0.3125
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 277 | 46976/47104] loss: 0.3750
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 278 | 46976/47104] loss: 0.3594
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 279 | 46976/47104] loss: 0.3594
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 280 | 46976/47104] loss: 0.3985
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 281 | 46976/47104] loss: 0.3057
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 282 | 46976/47104] loss: 0.4377
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 283 | 46976/47104] loss: 0.3359
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 284 | 46976/47104] loss: 0.3984
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 285 | 46976/47104] loss: 0.3594
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 286 | 46976/47104] loss: 0.3203
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 287 | 46976/47104] loss: 0.3750
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 288 | 46976/47104] loss: 0.3283
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 289 | 46976/47104] loss: 0.3750
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 290 | 46976/47104] loss: 0.3281
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 291 | 46976/47104] loss: 0.3282
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 292 | 46976/47104] loss: 0.3360
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 293 | 46976/47104] loss: 0.3674
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 294 | 46976/47104] loss: 0.3438
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 295 | 46976/47104] loss: 0.3750
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 296 | 46976/47104] loss: 0.3906
#   Training  | Loss:0.4842
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 297 | 46976/47104] loss: 0.4297
#   Training  | Loss:0.4841
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 298 | 46976/47104] loss: 0.3281
#   Training  | Loss:0.4841
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 299 | 46976/47104] loss: 0.3672
#   Training  | Loss:0.4839
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 300 | 46976/47104] loss: 0.3672
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 301 | 46976/47104] loss: 0.3906
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 302 | 46976/47104] loss: 0.3438
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 303 | 46976/47104] loss: 0.3594
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 304 | 46976/47104] loss: 0.3594
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 305 | 46976/47104] loss: 0.3516
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 306 | 46976/47104] loss: 0.3984
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 307 | 46976/47104] loss: 0.3049
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 308 | 46976/47104] loss: 0.3828
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 309 | 46976/47104] loss: 0.3829
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 310 | 46976/47104] loss: 0.3125
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 311 | 46976/47104] loss: 0.3438
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 312 | 46976/47104] loss: 0.4063
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 313 | 46976/47104] loss: 0.3438
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 314 | 46976/47104] loss: 0.3594
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 315 | 46976/47104] loss: 0.3751
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 316 | 46976/47104] loss: 0.3516
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 317 | 46976/47104] loss: 0.3203
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 318 | 46976/47104] loss: 0.3594
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 319 | 46976/47104] loss: 0.3828
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 320 | 46976/47104] loss: 0.3672
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 321 | 46976/47104] loss: 0.3359
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 322 | 46976/47104] loss: 0.3623
#   Training  | Loss:0.4822
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 323 | 46976/47104] loss: 0.4063
#   Training  | Loss:0.4822
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 324 | 46976/47104] loss: 0.4143
#   Training  | Loss:0.4822
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 325 | 46976/47104] loss: 0.3673
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 326 | 46976/47104] loss: 0.3828
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 327 | 46976/47104] loss: 0.3906
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 328 | 46976/47104] loss: 0.3281
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 329 | 46976/47104] loss: 0.3828
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 330 | 46976/47104] loss: 0.3750
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 331 | 46976/47104] loss: 0.3047
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 332 | 46976/47104] loss: 0.3984
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 333 | 46976/47104] loss: 0.4141
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 334 | 46976/47104] loss: 0.3672
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 335 | 46976/47104] loss: 0.3829
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 336 | 46976/47104] loss: 0.3984
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 337 | 46976/47104] loss: 0.3359
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 338 | 46976/47104] loss: 0.3672
#   Training  | Loss:0.4821
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 339 | 46976/47104] loss: 0.4063
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 340 | 46976/47104] loss: 0.4141
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 341 | 46976/47104] loss: 0.3281
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 342 | 46976/47104] loss: 0.3672
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 343 | 46976/47104] loss: 0.3906
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 344 | 46976/47104] loss: 0.3672
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 345 | 46976/47104] loss: 0.3516
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 346 | 46976/47104] loss: 0.2969
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 347 | 46976/47104] loss: 0.3595
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 348 | 46976/47104] loss: 0.3281
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 349 | 46976/47104] loss: 0.4219
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 350 | 46976/47104] loss: 0.3750
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 351 | 46976/47104] loss: 0.3438
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 352 | 46976/47104] loss: 0.3984
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 353 | 46976/47104] loss: 0.3281
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 354 | 46976/47104] loss: 0.4141
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 355 | 46976/47104] loss: 0.3125
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 356 | 46976/47104] loss: 0.3828
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 357 | 46976/47104] loss: 0.3906
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 358 | 46976/47104] loss: 0.3907
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 359 | 46976/47104] loss: 0.3828
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 360 | 46976/47104] loss: 0.3516
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 361 | 46976/47104] loss: 0.3828
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 362 | 46976/47104] loss: 0.3750
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 363 | 46976/47104] loss: 0.2969
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 364 | 46976/47104] loss: 0.3984
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 365 | 46976/47104] loss: 0.3672
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 366 | 46976/47104] loss: 0.3594
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 367 | 46976/47104] loss: 0.4375
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
#
# [Epoch 368 | 46976/47104] loss: 0.3281
#   Training  | Loss:0.4820
#  Validation | Loss:0.3737
# saving model with loss 0.3737...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-9432187bfa69> in <module>
#       1 device = 'cuda:0'
#       2 model = Net().to(device)
# ----> 3 model = train(train_dataloader, val_dataloader, model, n_epoch, batch, lr, device)
#
# <ipython-input-58-252d7c3c4e8b> in train(train_data, val_data, model, n_epoch, batch, lr, device)
#      35                 best_loss = total_loss
#      36                 print("saving model with loss %.4f...\n" % total_loss)
# ---> 37                 torch.save(model.state_dict(), "%s" % "model.pth")
#      38     return model
#
# /usr/local/lib/python3.8/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     421     if _use_new_zipfile_serialization:
#     422         with _open_zipfile_writer(f) as opened_zipfile:
# --> 423             _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     424             return
#     425     else:
#
# /usr/local/lib/python3.8/dist-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     648         # Now that it is on the CPU we can directly copy it into the zip file
#     649         num_bytes = storage.nbytes()
# --> 650         zip_file.write_record(name, storage.data_ptr(), num_bytes)
#     651
#     652
#
# KeyboardInterrupt:

# %% [markdown]
# # Result

# %%
best_model = model
#best_model.load_state_dict(torch.load("model.pth"))
best_model = best_model.eval()

testset = TestDataset()
test_dataloader = DataLoader(testset, 1, False)
result = []
for x, _ in test_dataloader:
    x = x.to(device)
    result.append(best_model(x).item())
print(max(result))
# Out:
# 0.013773455284535885

# %%
keys_to_predict = sorted(ESun_public_y_answer['alert_key'].values.tolist())
pairs = np.array(list(zip(keys_to_predict, result)))
sorted_pairs = np.flip(pairs[pairs[:, 1].argsort()], 0)
print(sorted_pairs)
# Out:
# [[3.58212000e+05 1.37734553e-02]
#  [3.56763000e+05 1.37734553e-02]
#  [3.60827000e+05 2.68448121e-03]
#  ...
#  [3.60597000e+05 0.00000000e+00]
#  [3.60598000e+05 0.00000000e+00]
#  [3.52249000e+05 0.00000000e+00]]

# %%
index_list = []
SAR_count = 0
for key, flag in ESun_public_y_answer.values.tolist():
    if flag == 1:
        SAR_count += 1
        for idx in range(len(sorted_pairs)):
            if key == sorted_pairs[idx][0]:
                index_list.append(idx + 1)
                break
print(len(index_list))
print(SAR_count)
index_list.sort()
print(index_list[-2])
print("score: ", str((SAR_count - 1) / index_list[-2]))

# 0.01, 0.05, 0.1, 0.3
# Out:
# 11
# 11
# 1385
# score:  0.007220216606498195

# %%
with open('predict.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['alert_key','probability'])
    for row in sorted_pairs:
        writer.writerow([int(row[0]), row[1]])
